# %%
from pathlib import Path
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns; sns.set()

# %matplotlib inline
ns = [3, 4, 5, 10]
def df(pattern):
    path = next(Path('/log').glob(pattern))
    array = np.load(str(path))
    n, d = array.shape
    indices = np.tile(np.arange(d), n)
    return pd.DataFrame(dict(y=array.flatten(), x=indices, pattern=pattern))


def plot(*patterns, kind="line", ci="sd",**kwargs):
    data = pd.concat(df(p) for p in patterns)
    sns.relplot(x="x", y="y", hue="pattern", kind=kind, ci=ci, data=data);
    
for n in ns:
    plot(f'*/TeacherTrainer_{n}_*/infos_coefficient.npy')
# Out:
# [          y    x                                     pattern
# 0       1.0    0  */TeacherTrainer_1_*/infos_coefficient.npy
# 1       1.0    1  */TeacherTrainer_1_*/infos_coefficient.npy
# 2       1.0    2  */TeacherTrainer_1_*/infos_coefficient.npy
# 3       1.0    3  */TeacherTrainer_1_*/infos_coefficient.npy
# 4       1.0    4  */TeacherTrainer_1_*/infos_coefficient.npy
# ...     ...  ...                                         ...
# 149695  1.0  993  */TeacherTrainer_1_*/infos_coefficient.npy
# 149696  1.0  994  */TeacherTrainer_1_*/infos_coefficient.npy
# 149697  1.0  995  */TeacherTrainer_1_*/infos_coefficient.npy
# 149698  1.0  996  */TeacherTrainer_1_*/infos_coefficient.npy
# 149699  1.0  997  */TeacherTrainer_1_*/infos_coefficient.npy
#
# [149700 rows x 3 columns]]

# %%
plot(f'*/TeacherTrainer_{n}_*/infos_baseline_regret.npy', f'*/TeacherTrainer_{n}_*/infos_regret.npy')
# Out:
# [          y    x                                         pattern
# 0       1.0    0  */TeacherTrainer_1_*/infos_baseline_regret.npy
# 1       1.0    1  */TeacherTrainer_1_*/infos_baseline_regret.npy
# 2       1.0    2  */TeacherTrainer_1_*/infos_baseline_regret.npy
# 3       1.0    3  */TeacherTrainer_1_*/infos_baseline_regret.npy
# 4       1.0    4  */TeacherTrainer_1_*/infos_baseline_regret.npy
# ...     ...  ...                                             ...
# 149695  0.0  993  */TeacherTrainer_1_*/infos_baseline_regret.npy
# 149696  0.0  994  */TeacherTrainer_1_*/infos_baseline_regret.npy
# 149697  0.0  995  */TeacherTrainer_1_*/infos_baseline_regret.npy
# 149698  0.0  996  */TeacherTrainer_1_*/infos_baseline_regret.npy
# 149699  0.0  997  */TeacherTrainer_1_*/infos_baseline_regret.npy
#
# [149700 rows x 3 columns],           y    x                                pattern
# 0       1.0    0  */TeacherTrainer_1_*/infos_regret.npy
# 1       1.0    1  */TeacherTrainer_1_*/infos_regret.npy
# 2       1.0    2  */TeacherTrainer_1_*/infos_regret.npy
# 3       1.0    3  */TeacherTrainer_1_*/infos_regret.npy
# 4       1.0    4  */TeacherTrainer_1_*/infos_regret.npy
# ...     ...  ...                                    ...
# 149695  0.0  993  */TeacherTrainer_1_*/infos_regret.npy
# 149696  0.0  994  */TeacherTrainer_1_*/infos_regret.npy
# 149697  0.0  995  */TeacherTrainer_1_*/infos_regret.npy
# 149698  0.0  996  */TeacherTrainer_1_*/infos_regret.npy
# 149699  0.0  997  */TeacherTrainer_1_*/infos_regret.npy
#
# [149700 rows x 3 columns]]
