# %%
from pathlib import Path
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline



def plot(pat, color=None):
    for path in Path('/log').glob(pat):
        array = np.load(str(path)).mean(0)
        plt.plot(array, color=color)
n = 7
plot(f'*/TeacherTrainer_{n}_*/infos_coefficient.npy')

# %%
plot(f'*/TeacherTrainer_{n}_*/infos_baseline_regret.npy', color='red')
plot(f'*/TeacherTrainer_{n}_*/infos_regret.npy', color='green')
